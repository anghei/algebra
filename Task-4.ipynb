# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot()
k = 1
x = np.linspace(-10, 10, 200)
plt.plot(x, np.cos(k*x))
k = 2
plt.plot(x, np.cos(k*x))
plt.show()
